# %% [markdown]
# > In this project I named binary label images to mask and soft label(0 ~ 1) to alpha

# %%
import numpy as np
import sklearn.neighbors
import scipy.sparse
import warnings

import matplotlib.pyplot as plt
import scipy.misc

import cv2
import os

# %%
import cv2 as cv
from time import time
from PIL import Image

import torch
import torch.nn as nn

# %%
import cv2 as cv
from time import time
from PIL import Image

import torch
import torch.nn as nn
from indexnet.hlmobilenetv2 import hlmobilenetv2

# ignore warnings
import warnings
warnings.filterwarnings("ignore")

IMG_SCALE = 1./255
IMG_MEAN = np.array([0.485, 0.456, 0.406, 0]).reshape((1, 1, 4))
IMG_STD = np.array([0.229, 0.224, 0.225, 1]).reshape((1, 1, 4))

STRIDE = 32
RESTORE_FROM = './pretrained/indexnet_matting.pth.tar'
RESULT_DIR = './examples/mattes'

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

if not os.path.exists(RESULT_DIR):
    os.makedirs(RESULT_DIR)

# load pretrained model
net = hlmobilenetv2(
        pretrained=False,
        freeze_bn=True, 
        output_stride=STRIDE,
        apply_aspp=True,
        conv_operator='std_conv',
        decoder='indexnet',
        decoder_kernel_size=5,
        indexnet='depthwise',
        index_mode='m2o',
        use_nonlinear=True,
        use_context=True
    )
net = nn.DataParallel(net)
try:
    checkpoint = torch.load(RESTORE_FROM, map_location=torch.device('cpu'))
    pretrained_dict = checkpoint['state_dict']
except:
    raise Exception('Please download the pretrained model!')
net.load_state_dict(pretrained_dict)
net.to(device)

# switch to eval mode
net.eval()
# Out:
# DataParallel(
#   (module): hlMobileNetV2UNetDecoderIndexLearning(
#     (layer0): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(3, 3), stride=1, padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (layer1): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (layer2): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), groups=96, bias=False)
#           (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False)
#           (4): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (layer3): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False)
#           (4): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False)
#           (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False)
#           (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (layer4): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False)
#           (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), groups=384, bias=False)
#           (4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), groups=384, bias=False)
#           (4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), groups=384, bias=False)
#           (4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (layer5): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), groups=384, bias=False)
#           (4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), groups=576, bias=False)
#           (4): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), groups=576, bias=False)
#           (4): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (layer6): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), groups=576, bias=False)
#           (4): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False)
#           (4): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False)
#           (4): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (layer7): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False)
#           (4): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (index0): DepthwiseM2OIndexBlock(
#       (indexnet1): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet2): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet3): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet4): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (index2): DepthwiseM2OIndexBlock(
#       (indexnet1): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet2): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet3): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet4): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (index3): DepthwiseM2OIndexBlock(
#       (indexnet1): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet2): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet3): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet4): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (index4): DepthwiseM2OIndexBlock(
#       (indexnet1): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet3): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet4): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (index6): DepthwiseM2OIndexBlock(
#       (indexnet1): Sequential(
#         (0): Conv2d(160, 160, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet2): Sequential(
#         (0): Conv2d(160, 160, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet3): Sequential(
#         (0): Conv2d(160, 160, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (indexnet4): Sequential(
#         (0): Conv2d(160, 160, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (dconv_pp): ASPP(
#       (aspp1): _ASPPModule(
#         (atrous_conv): Sequential(
#           (0): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#       )
#       (aspp2): _ASPPModule(
#         (atrous_conv): Sequential(
#           (0): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), groups=320, bias=False)
#           (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#         )
#       )
#       (aspp3): _ASPPModule(
#         (atrous_conv): Sequential(
#           (0): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), groups=320, bias=False)
#           (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#         )
#       )
#       (aspp4): _ASPPModule(
#         (atrous_conv): Sequential(
#           (0): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(8, 8), dilation=(8, 8), groups=320, bias=False)
#           (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#         )
#       )
#       (global_avg_pool): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=(1, 1))
#         (1): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU6(inplace=True)
#       )
#       (bottleneck_conv): Sequential(
#         (0): Conv2d(1280, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#     (decoder_layer6): IndexedUpsamlping(
#       (dconv): Sequential(
#         (0): Conv2d(320, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#         (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (decoder_layer5): IndexedUpsamlping(
#       (dconv): Sequential(
#         (0): Conv2d(192, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (decoder_layer4): IndexedUpsamlping(
#       (dconv): Sequential(
#         (0): Conv2d(128, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (decoder_layer3): IndexedUpsamlping(
#       (dconv): Sequential(
#         (0): Conv2d(64, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (decoder_layer2): IndexedUpsamlping(
#       (dconv): Sequential(
#         (0): Conv2d(48, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#         (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (decoder_layer1): IndexedUpsamlping(
#       (dconv): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (decoder_layer0): IndexedUpsamlping(
#       (dconv): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (pred): Sequential(
#       (0): Sequential(
#         (0): Conv2d(32, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#     )
#   )
# )

# %%
def load_img_mask_pair(img_path):
    
    mask_path = img_path.split(".p")[0] + "_matte.png"
    
    if 'Supervisely' in mask_path:
        
        mask_path = mask_path.replace("/img/", "/masks_machine/")
        mask_path = mask_path.replace(".jpeg", "")
        
    img = cv2.imread(img_path, cv2.IMREAD_COLOR)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    
    mask *= 255
    
    img = cv2.resize(img, (1024, 1024))
    mask = cv2.resize(mask, (1024, 1024))
    
    return img, mask

# %%
def make_trimap(mask, size=(10, 10)):

    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, size)
    mask = mask / 255.

    dilated = cv2.dilate(mask, kernel, iterations=1) * 255
    eroded = cv2.erode(mask, kernel, iterations=1) * 255

    cnt1 = len(np.where(mask >= 0)[0])
    cnt2 = len(np.where(mask == 0)[0])
    cnt3 = len(np.where(mask == 1)[0])
    
    #print("all:{} bg:{} fg:{}".format(cnt1, cnt2, cnt3))
    
    assert(cnt1 == cnt2 + cnt3)
    
    cnt1 = len(np.where(dilated >= 0)[0])
    cnt2 = len(np.where(dilated == 0)[0])
    cnt3 = len(np.where(dilated == 255)[0])
    
    #print("all:{} bg:{} fg:{}".format(cnt1, cnt2, cnt3))
    assert(cnt1 == cnt2 + cnt3)

    cnt1 = len(np.where(eroded >= 0)[0])
    cnt2 = len(np.where(eroded == 0)[0])
    cnt3 = len(np.where(eroded == 255)[0])
    #print("all:{} bg:{} fg:{}".format(cnt1, cnt2, cnt3))
    assert(cnt1 == cnt2 + cnt3)

    trimap = dilated.copy()
    
    trimap[((dilated == 255) & (eroded == 0))] = 128

    return trimap

# %%
# from INdexNet
def read_image(x):
    img_arr = np.array(Image.open(x))
    return img_arr

def save_alpha(target_name, alpha):

    cv2.imwrite(target_name, alpha*255)
    
    return 1

# %%
def image_alignment(x, output_stride, odd=False):
    imsize = np.asarray(x.shape[:2], dtype=np.float)
    if odd:
        new_imsize = np.ceil(imsize / output_stride) * output_stride + 1
    else:
        new_imsize = np.ceil(imsize / output_stride) * output_stride
    h, w = int(new_imsize[0]), int(new_imsize[1])

    x1 = x[:, :, 0:3]
    x2 = x[:, :, 3]
    new_x1 = cv.resize(x1, dsize=(w,h), interpolation=cv.INTER_CUBIC)
    new_x2 = cv.resize(x2, dsize=(w,h), interpolation=cv.INTER_NEAREST)

    new_x2 = np.expand_dims(new_x2, axis=2)
    new_x = np.concatenate((new_x1, new_x2), axis=2)

    return new_x

# %% [markdown]
# # Actual Logic

# %%
def inference(image_path):

    alpha_path = image_path.replace("/img/", "/alpha/")
    image, mask = load_img_mask_pair(img_path)
    trimap = make_trimap(mask, size=(20, 20))
    
    with torch.no_grad():
#         image, trimap = read_image(image_path), read_image(trimap_path)
        trimap = np.expand_dims(trimap, axis=2)
        image = np.concatenate((image, trimap), axis=2)
        
        h, w = image.shape[:2]

        image = image.astype('float32')
        image = (IMG_SCALE * image - IMG_MEAN) / IMG_STD
        image = image.astype('float32')

        image = image_alignment(image, STRIDE)
        inputs = torch.from_numpy(np.expand_dims(image.transpose(2, 0, 1), axis=0))
        #inputs = inputs.cuda()
        
        # inference
        start = time()
        outputs = net(inputs)
        end = time()

        outputs = outputs.squeeze().cpu().numpy()
        alpha = cv.resize(outputs, dsize=(w,h), interpolation=cv.INTER_CUBIC)
        alpha = np.clip(alpha, 0, 1) * 255.
        trimap = trimap.squeeze()
        mask = np.equal(trimap, 128).astype(np.float32)
        alpha = (1 - mask) * trimap + mask * alpha

        _, image_name = os.path.split(image_path)
        Image.fromarray(alpha.astype(np.uint8)).save(os.path.join(alpha_path))
        # Image.fromarray(alpha.astype(np.uint8)).show()

        running_frame_rate = 1 * float(1 / (end - start)) # batch_size = 1
        print('framerate: {0:.2f}Hz'.format(running_frame_rate))
        return alpha.astype(np.uint8)

# %%
DATASET_BASE = "./dataset/Supervisely_person_dataset"

# %%
dslist = [ds for ds in os.listdir(DATASET_BASE) if "." not in ds]

# %%
dslist[5:]
# Out:
# ['ds9', 'ds7', 'ds2', 'ds5', 'ds13', 'ds12', 'ds4', 'ds3']

# %%
# test
for ds in dslist[5:6]:
    
    img_dir = os.path.join(DATASET_BASE, ds, "img")
    alpha_dir = os.path.join(DATASET_BASE, ds, "alpha")

    if not os.path.exists(alpha_dir):
        os.mkdir(alpha_dir)
        
    img_list = [os.path.join(DATASET_BASE, ds, "img", i) for i in os.listdir(img_dir)]
    
#     for img_path in img_list:
        
        
#         alpha = inference(img_path)
#         print(img_path, "is done")
        
# #         plt.imshow(alpha, cmap='gray')
# #         plt.show()
# #         break
# #     break

# %%
img_list
# Out:
# ['./dataset/Supervisely_person_dataset/ds9/img/pexels-photo-878783.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-873417.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-269920.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-878782.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-867852.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-867846.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-877699.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-881669.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-866019.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-838574.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-878346.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-114794.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-865713.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879474.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-863986.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-863944.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-872732.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879471.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-859992.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-866023.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879117.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-876393.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-869516.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879249.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-883441.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-866817.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879472.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-878787.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879415.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-868097.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-872756.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-881033.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-863061.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-878119.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-865773.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-872596.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-865003.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-880474.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-865349.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879012.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879589.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-881233.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-881757.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-866866.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-321441.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-881623.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-258545.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-865943.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-881633.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-863098.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-880465.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-863067.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-883434.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-450597.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-872432.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-883435.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-873513.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-868866.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-874283.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-452544.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-884548.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-257473.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-874242.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-868440.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-881590.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-884417.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-784754.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-878684.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-876285.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-872593.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-878716.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879805.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-878689.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-872602.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-870798.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-853155.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-174753.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-878717.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-884551.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-871484.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-880482.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-860562.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-878846.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-884419.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-884418.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-860563.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-860577.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-871491.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879807.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-859057.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-867181.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-880929.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-865580.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-868113.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-279357.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-880861.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-884421.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-871494.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879143.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-876714.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-871053.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879357.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-884423.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-884422.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-881638.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-560715.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-873422.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-864994.png',
#  './dataset/Supervisely_person_dataset/ds9/img/human-people-singapore-couple-79690.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-878358.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-135020.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-874158.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-877121.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-873421.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-875722.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-866819.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-866366.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-880806.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-864000.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-863974.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-868548.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-873418.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-867524.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-866821.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879120.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879485.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-859191.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-808862.png',
#  './dataset/Supervisely_person_dataset/ds9/img/pexels-photo-879651.png']

# %% [markdown]
# ## legacy

# %%
# it is too slow
# borrow from 'https://github.com/MarcoForte/knn-matting'
# nn = 10
def knn_matte(img, trimap, mylambda=100):
    
    [m, n, c] = img.shape
    
    img, trimap = img / 255.0, trimap / 255.0
    
    foreground = (trimap > 0.99).astype(int)
    background = (trimap < 0.01).astype(int)
    print(foreground.shape)
    print(background.shape)
    
    all_constraints = foreground + background
    print(all_constraints.shape)

    print('Finding nearest neighbors')
    
    a, b = np.unravel_index(np.arange(m*n), (m, n))
    print("a", a)
    print("b", b)
    
    feature_vec = np.append(np.transpose(img.reshape(m*n,c)), [a, b]/np.sqrt(m*m + n*n), axis=0).T
    
    nbrs = sklearn.neighbors.NearestNeighbors(n_neighbors=10).fit(feature_vec)
    knns = nbrs.kneighbors(feature_vec)[1]
    print(knns.shape)

    # Compute Sparse A
    print('Computing sparse A')
    row_inds = np.repeat(np.arange(m*n), 10)
    col_inds = knns.reshape(m*n*10)
    
    vals = 1 - np.linalg.norm(feature_vec[row_inds] - feature_vec[col_inds], axis=1)/(c+2)
    A = scipy.sparse.coo_matrix((vals, (row_inds, col_inds)),shape=(m*n, m*n))

    D_script = scipy.sparse.diags(np.ravel(A.sum(axis=1)))
    
    L = D_script-A
#     D = scipy.sparse.diags(np.ravel(all_constraints[:,:, 0]))
    D = scipy.sparse.diags(np.ravel(all_constraints[:,:]))
#     v = np.ravel(foreground[:,:,0])
    v = np.ravel(foreground[:,:])
    c = 2*mylambda*np.transpose(v)
    H = 2*(L + mylambda*D)

    print('Solving linear system for alpha')
    warnings.filterwarnings('error')
    alpha = []
    try:
        alpha = np.minimum(np.maximum(scipy.sparse.linalg.spsolve(H, c), 0), 1).reshape(m, n)
    except Warning:
        x = scipy.sparse.linalg.lsqr(H, c)
        alpha = np.minimum(np.maximum(x[0], 0), 1).reshape(m, n)
    return alpha
